# %%
import arcgis

# %%
help(arcgis)
# Out:
# Help on package arcgis:
#
# NAME
#     arcgis
#
# PACKAGE CONTENTS
#     _impl (package)
#     apps (package)
#     env
#     features (package)
#     geoanalytics (package)
#     geocoding (package)
#     geoenrichment (package)
#     geometry (package)
#     geoprocessing (package)
#     gis (package)
#     install
#     mapping (package)
#     network (package)
#     raster (package)
#     realtime (package)
#     schematics (package)
#     widgets (package)
#
# CLASSES
#     builtins.object
#         arcgis.gis.GIS
#
#     class GIS(builtins.object)
#      |  .. _gis:
#      |
#      |  A GIS is representative of a single ArcGIS Online organization or an ArcGIS Enterprise deployment. The GIS object
#      |  provides helper objects to manage (search, create, retrieve) GIS resources such as content, users, and groups.
#      |
#      |  Additionally, the GIS object has properties to query its state, which is accessible using the properties attribute.
#      |
# ...

# %%
gis = arcgis.gis.GIS("https://insights.mapsdevext.arcgis.com/", "clint.dow", "@1492DataInsights")

# %%
gis
# Out:
# GIS @ <a href="https://insights.mapsdevext.arcgis.com">https://insights.mapsdevext.arcgis.com</a>

# %%
gis?

# %%
gis.groups

# %%
gis.groups.search('Python')
# Out:
# [<Group title:"PythonTest" owner:clint.dow>]

# %%
gis.users

# %%
me = gis.users.get('clint.dow')

# %%
me
# Out:
# <User username:clint.dow>

# %%
type(me)
# Out:
# arcgis.gis.User

# %%
me.keys()
# Out:
# dict_keys(['username', 'fullName', 'firstName', 'lastName', 'preferredView', 'description', 'email', 'userType', 'idpUsername', 'favGroupId', 'lastLogin', 'mfaEnabled', 'access', 'storageUsage', 'storageQuota', 'orgId', 'role', 'privileges', 'level', 'disabled', 'tags', 'culture', 'cultureFormat', 'region', 'units', 'thumbnail', 'created', 'modified', 'provider', 'groups'])

# %%
dir(gis)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_timestamp_to_profile_data_in_config',
#  '_cert_file',
#  '_client_id',
#  '_con',
#  '_config_is_in_new_format',
#  '_current_keyring_is_recommended',
#  '_datastores',
#  '_datastores_list',
#  '_get_keyring_failure_message',
#  '_get_properties',
#  '_key_file',
#  '_lazy_groups',
#  '_lazy_properties',
#  '_lazy_users',
#  '_password',
#  '_pfx_to_pem',
#  '_portal',
#  '_proxy_host',
#  '_proxy_port',
#  '_referer',
#  '_repr_html_',
#  '_securely_delete_password',
#  '_securely_get_password',
#  '_securely_store_password',
#  '_server_list',
#  '_tools',
# ...

# %%
c = [content for content in gis.content]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8ebea7875833> in <module>()
# ----> 1 c = [content for content in gis.content]
#
# TypeError: 'ContentManager' object is not iterable

# %%
c = gis.content.search('')

# %%
c
# Out:
# [<Item title:"CambodiaAreas" type:Insights Model owner:yelouri_insights9>,
#  <Item title:"test Page 1test2" type:Insights Page owner:admini>,
#  <Item title:"ShareData_5k.Table5k" type:Feature Layer Collection owner:publisher@insights>,
#  <Item title:"Determining how places are related" type:Insights Model owner:mhovorka@insights>,
#  <Item title:"Modelbbb" type:Insights Model owner:shirley@insights>,
#  <Item title:"USA_Roads" type:Feature Layer Collection owner:admini>,
#  <Item title:"Figuring Cost of Snow Removal Model" type:Insights Model owner:mhovorka@insights>,
#  <Item title:"Model" type:Insights Model owner:mhovorka@insights>,
#  <Item title:"6581 Page 2" type:Insights Page owner:yelouri_insights9>,
#  <Item title:"Trees" type:Feature Layer Collection owner:admini>]

# %%
c = gis.content.search('type:Insights')

# %%
c
# Out:
# [<Item title:"CambodiaAreas" type:Insights Model owner:yelouri_insights9>,
#  <Item title:"test Page 1test2" type:Insights Page owner:admini>,
#  <Item title:"Determining how places are related" type:Insights Model owner:mhovorka@insights>,
#  <Item title:"Modelbbb" type:Insights Model owner:shirley@insights>,
#  <Item title:"Figuring Cost of Snow Removal Model" type:Insights Model owner:mhovorka@insights>,
#  <Item title:"Model" type:Insights Model owner:mhovorka@insights>,
#  <Item title:"6581 Page 2" type:Insights Page owner:yelouri_insights9>,
#  <Item title:"RatesOfTouching" type:Insights Model owner:yelouri_insights9>,
#  <Item title:"Akshay 3" type:Insights Page owner:tester@insights>,
#  <Item title:"ModelSafari-NewSB" type:Insights Model owner:admini>]

# %%
c = gis.content.search('owner:clint.dow')

# %%
c
# Out:
# [<Item title:"Untitled Workbook" type:Insights Workbook owner:clint.dow>]

# %%
c = gis.content.search('type:Insights Workbook')

# %%
c
# Out:
# [<Item title:"Analytics for Snow Operations" type:Insights Workbook owner:mhovorka@insights>,
#  <Item title:"Untitled Workbook Page 1b" type:Insights Page owner:tester@insights>,
#  <Item title:"Untitled Workbook" type:Insights Workbook owner:mhovorka@insights>,
#  <Item title:"Untitled Workbook" type:Insights Workbook owner:mhovorka@insights>,
#  <Item title:"Admin AW" type:Insights Workbook owner:dburlo_admin>,
#  <Item title:"Untitled Workbook Page 1" type:Insights Page owner:daniel@insights>,
#  <Item title:"Trevor JMeter Workbook Load Test Workflow" type:Insights Page owner:admini>,
#  <Item title:"Untitled Workbook" type:Insights Workbook owner:admini>,
#  <Item title:"label share" type:Insights Workbook owner:shirley@insights>,
#  <Item title:"Jose200kFeatures031418" type:Insights Workbook owner:tester@insights>]

# %%
c = gis.content.search('type:Insights Workbook owner:clint.dow')

# %%
c
# Out:
# [<Item title:"Untitled Workbook" type:Insights Workbook owner:clint.dow>]

# %%
props = gis.properties

# %%
props
# Out:
# {
#   "access": "private",
#   "allSSL": true,
#   "allowedRedirectUris": [],
#   "analysisLayersGroupQuery": "title:\"Living Atlas Analysis Layers\" AND owner:esri",
#   "authorizedCrossOriginDomains": [],
#   "availableCredits": 78296.82,
#   "backgroundImage": "images/arcgis_background.jpg",
#   "basemapGalleryGroupQuery": "id:c055425dc315426ca956bc301ed3aef5",
#   "canListApps": false,
#   "canListData": false,
#   "canListPreProvisionedItems": false,
#   "canProvisionDirectPurchase": false,
#   "canSearchPublic": true,
#   "canSetCustomBuyLink": false,
#   "canSetQuestionnaire": false,
#   "canShareBingPublic": false,
#   "canSharePublic": true,
#   "canSignInArcGIS": true,
#   "canSignInIDP": true,
#   "colorSetsGroupQuery": "title:\"Esri Colors\" AND owner:esri_en",
#   "commentsEnabled": true,
#   "contentCategorySetsGroupQuery": "title:\"ArcGIS Online Content Category Sets\" AND owner:esri_en",
#   "created": 1440541268000,
#   "culture": "en-US",
#   "cultureFormat": "us",
# ...

# %%
dir(gis)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_timestamp_to_profile_data_in_config',
#  '_cert_file',
#  '_client_id',
#  '_con',
#  '_config_is_in_new_format',
#  '_current_keyring_is_recommended',
#  '_datastores',
#  '_datastores_list',
#  '_get_keyring_failure_message',
#  '_get_properties',
#  '_key_file',
#  '_lazy_content',
#  '_lazy_groups',
#  '_lazy_properties',
#  '_lazy_users',
#  '_password',
#  '_pfx_to_pem',
#  '_portal',
#  '_proxy_host',
#  '_proxy_port',
#  '_referer',
#  '_repr_html_',
#  '_securely_delete_password',
#  '_securely_get_password',
#  '_securely_store_password',
# ...

# %%
gis._username
# Out:
# 'clint.dow'

# %%
gis._portal

# %%
p = gis._portal

# %%
p.resturl
# Out:
# 'https://insights.mapsdevext.arcgis.com/sharing/rest/'

# %%
dir(me)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_gis',
#  '_hydrate',
#  '_hydrated',
#  '_portal',
#  '_repr_html_',
#  '_workdir',
#  'access',
#  'clear',
#  'copy',
#  'created',
#  'culture',
#  'cultureFormat',
#  'delete',
#  'description',
#  'disable',
#  'disabled',
#  'download_thumbnail',
#  'email',
#  'enable',
#  'esri_access',
#  'favGroupId',
#  'firstName',
#  'folders',
#  'fromkeys',
#  'fullName',
#  'get',
#  'get_thumbnail',
#  'get_thumbnail_link',
#  'groups',
# ...

# %%
me._portal.resturl
# Out:
# 'https://insights.mapsdevext.arcgis.com/sharing/rest/'

# %%
me._portal.orgId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-0bc82b7cdd6d> in <module>()
# ----> 1 me._portal.orgId
#
# AttributeError: 'Portal' object has no attribute 'orgId'

# %%
me.orgId
# Out:
# 'gKIM0DxFtj9ijTZo'
